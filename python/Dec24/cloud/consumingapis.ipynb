# %% [markdown]
# # Consuming rest apis from python

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in c:\khajaclassroom\python\dec24\cloud\venv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\khajaclassroom\python\dec24\cloud\venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\khajaclassroom\python\dec24\cloud\venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\khajaclassroom\python\dec24\cloud\venv\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\khajaclassroom\python\dec24\cloud\venv\lib\site-packages (from requests) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # API Reference documentation
#
# * [docs](https://fakestoreapi.com/docs)

# %%
import requests

PRODUCTS_URL = "https://fakestoreapi.com/products"

# %%
response = requests.get(PRODUCTS_URL)
print(type(response))
# Out:
# <class 'requests.models.Response'>

# %%
status_code = response.status_code
status_code
# Out:
# 200

# %%
# Get the response
products = response.json()
type(products)
# Out:
# list

# %%
for product in products:
    print(product)
# Out:
# {'id': 1, 'title': 'Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops', 'price': 109.95, 'description': 'Your perfect pack for everyday use and walks in the forest. Stash your laptop (up to 15 inches) in the padded sleeve, your everyday', 'category': "men's clothing", 'image': 'https://fakestoreapi.com/img/81fPKd-2AYL._AC_SL1500_.jpg', 'rating': {'rate': 3.9, 'count': 120}}
# {'id': 2, 'title': 'Mens Casual Premium Slim Fit T-Shirts ', 'price': 22.3, 'description': 'Slim-fitting style, contrast raglan long sleeve, three-button henley placket, light weight & soft fabric for breathable and comfortable wearing. And Solid stitched shirts with round neck made for durability and a great fit for casual fashion wear and diehard baseball fans. The Henley style round neckline includes a three-button placket.', 'category': "men's clothing", 'image': 'https://fakestoreapi.com/img/71-3HjGNDUL._AC_SY879._SX._UX._SY._UY_.jpg', 'rating': {'rate': 4.1, 'count': 259}}
# {'id': 3, 'title': 'Mens Cotton Jacket', 'price': 55.99, 'description': 'great outerwear jackets for Spring/Autumn/Winter, suitable for many occasions, such as working, hiking, camping, mountain/rock climbing, cycling, traveling or other outdoors. Good gift choice for you or your family member. A warm hearted love to Father, husband or son in this thanksgiving or Christmas Day.', 'category': "men's clothing", 'image': 'https://fakestoreapi.com/img/71li-ujtlUL._AC_UX679_.jpg', 'rating': {'rate': 4.7, 'count': 500}}
# {'id': 4, 'title': 'Mens Casual Slim Fit', 'price': 15.99, 'description': 'The color could be slightly different between on the screen and in practice. / Please note that body builds vary by person, therefore, detailed size information should be reviewed below on the product description.', 'category': "men's clothing", 'image': 'https://fakestoreapi.com/img/71YXzeOuslL._AC_UY879_.jpg', 'rating': {'rate': 2.1, 'count': 430}}
# {'id': 5, 'title': "John Hardy Women's Legends Naga Gold & Silver Dragon Station Chain Bracelet", 'price': 695, 'description': "From our Legends Collection, the Naga was inspired by the mythical water dragon that protects the ocean's pearl. Wear facing inward to be bestowed with love and abundance, or outward for protection.", 'category': 'jewelery', 'image': 'https://fakestoreapi.com/img/71pWzhdJNwL._AC_UL640_QL65_ML3_.jpg', 'rating': {'rate': 4.6, 'count': 400}}
# {'id': 6, 'title': 'Solid Gold Petite Micropave ', 'price': 168, 'description': 'Satisfaction Guaranteed. Return or exchange any order within 30 days.Designed and sold by Hafeez Center in the United States. Satisfaction Guaranteed. Return or exchange any order within 30 days.', 'category': 'jewelery', 'image': 'https://fakestoreapi.com/img/61sbMiUnoGL._AC_UL640_QL65_ML3_.jpg', 'rating': {'rate': 3.9, 'count': 70}}
# {'id': 7, 'title': 'White Gold Plated Princess', 'price': 9.99, 'description': "Classic Created Wedding Engagement Solitaire Diamond Promise Ring for Her. Gifts to spoil your love more for Engagement, Wedding, Anniversary, Valentine's Day...", 'category': 'jewelery', 'image': 'https://fakestoreapi.com/img/71YAIFU48IL._AC_UL640_QL65_ML3_.jpg', 'rating': {'rate': 3, 'count': 400}}
# {'id': 8, 'title': 'Pierced Owl Rose Gold Plated Stainless Steel Double', 'price': 10.99, 'description': 'Rose Gold Plated Double Flared Tunnel Plug Earrings. Made of 316L Stainless Steel', 'category': 'jewelery', 'image': 'https://fakestoreapi.com/img/51UDEzMJVpL._AC_UL640_QL65_ML3_.jpg', 'rating': {'rate': 1.9, 'count': 100}}
# {'id': 9, 'title': 'WD 2TB Elements Portable External Hard Drive - USB 3.0 ', 'price': 64, 'description': 'USB 3.0 and USB 2.0 Compatibility Fast data transfers Improve PC Performance High Capacity; Compatibility Formatted NTFS for Windows 10, Windows 8.1, Windows 7; Reformatting may be required for other operating systems; Compatibility may vary depending on user’s hardware configuration and operating system', 'category': 'electronics', 'image': 'https://fakestoreapi.com/img/61IBBVJvSDL._AC_SY879_.jpg', 'rating': {'rate': 3.3, 'count': 203}}
# {'id': 10, 'title': 'SanDisk SSD PLUS 1TB Internal SSD - SATA III 6 Gb/s', 'price': 109, 'description': 'Easy upgrade for faster boot up, shutdown, application load and response (As compared to 5400 RPM SATA 2.5” hard drive; Based on published specifications and internal benchmarking tests using PCMark vantage scores) Boosts burst write performance, making it ideal for typical PC workloads The perfect balance of performance and reliability Read/write speeds of up to 535MB/s/450MB/s (Based on internal testing; Performance may vary depending upon drive capacity, host device, OS and application.)', 'category': 'electronics', 'image': 'https://fakestoreapi.com/img/61U7T1koQqL._AC_SX679_.jpg', 'rating': {'rate': 2.9, 'count': 470}}
# {'id': 11, 'title': 'Silicon Power 256GB SSD 3D NAND A55 SLC Cache Performance Boost SATA III 2.5', 'price': 109, 'description': '3D NAND flash are applied to deliver high transfer speeds Remarkable transfer speeds that enable faster bootup and improved overall system performance. The advanced SLC Cache Technology allows performance boost and longer lifespan 7mm slim design suitable for Ultrabooks and Ultra-slim notebooks. Supports TRIM command, Garbage Collection technology, RAID, and ECC (Error Checking & Correction) to provide the optimized performance and enhanced reliability.', 'category': 'electronics', 'image': 'https://fakestoreapi.com/img/71kWymZ+c+L._AC_SX679_.jpg', 'rating': {'rate': 4.8, 'count': 319}}
# {'id': 12, 'title': 'WD 4TB Gaming Drive Works with Playstation 4 Portable External Hard Drive', 'price': 114, 'description': "Expand your PS4 gaming experience, Play anywhere Fast and easy, setup Sleek design with high capacity, 3-year manufacturer's limited warranty", 'category': 'electronics', 'image': 'https://fakestoreapi.com/img/61mtL65D4cL._AC_SX679_.jpg', 'rating': {'rate': 4.8, 'count': 400}}
# {'id': 13, 'title': 'Acer SB220Q bi 21.5 inches Full HD (1920 x 1080) IPS Ultra-Thin', 'price': 599, 'description': '21. 5 inches Full HD (1920 x 1080) widescreen IPS display And Radeon free Sync technology. No compatibility for VESA Mount Refresh Rate: 75Hz - Using HDMI port Zero-frame design | ultra-thin | 4ms response time | IPS panel Aspect ratio - 16: 9. Color Supported - 16. 7 million colors. Brightness - 250 nit Tilt angle -5 degree to 15 degree. Horizontal viewing angle-178 degree. Vertical viewing angle-178 degree 75 hertz', 'category': 'electronics', 'image': 'https://fakestoreapi.com/img/81QpkIctqPL._AC_SX679_.jpg', 'rating': {'rate': 2.9, 'count': 250}}
# {'id': 14, 'title': 'Samsung 49-Inch CHG90 144Hz Curved Gaming Monitor (LC49HG90DMNXZA) – Super Ultrawide Screen QLED ', 'price': 999.99, 'description': '49 INCH SUPER ULTRAWIDE 32:9 CURVED GAMING MONITOR with dual 27 inch screen side by side QUANTUM DOT (QLED) TECHNOLOGY, HDR support and factory calibration provides stunningly realistic and accurate color and contrast 144HZ HIGH REFRESH RATE and 1ms ultra fast response time work to eliminate motion blur, ghosting, and reduce input lag', 'category': 'electronics', 'image': 'https://fakestoreapi.com/img/81Zt42ioCgL._AC_SX679_.jpg', 'rating': {'rate': 2.2, 'count': 140}}
# {'id': 15, 'title': "BIYLACLESEN Women's 3-in-1 Snowboard Jacket Winter Coats", 'price': 56.99, 'description': 'Note:The Jackets is US standard size, Please choose size as your usual wear Material: 100% Polyester; Detachable Liner Fabric: Warm Fleece. Detachable Functional Liner: Skin Friendly, Lightweigt and Warm.Stand Collar Liner jacket, keep you warm in cold weather. Zippered Pockets: 2 Zippered Hand Pockets, 2 Zippered Pockets on Chest (enough to keep cards or keys)and 1 Hidden Pocket Inside.Zippered Hand Pockets and Hidden Pocket keep your things secure. Humanized Design: Adjustable and Detachable Hood and Adjustable cuff to prevent the wind and water,for a comfortable fit. 3 in 1 Detachable Design provide more convenience, you can separate the coat and inner as needed, or wear it together. It is suitable for different season and help you adapt to different climates', 'category': "women's clothing", 'image': 'https://fakestoreapi.com/img/51Y5NI-I5jL._AC_UX679_.jpg', 'rating': {'rate': 2.6, 'count': 235}}
# {'id': 16, 'title': "Lock and Love Women's Removable Hooded Faux Leather Moto Biker Jacket", 'price': 29.95, 'description': '100% POLYURETHANE(shell) 100% POLYESTER(lining) 75% POLYESTER 25% COTTON (SWEATER), Faux leather material for style and comfort / 2 pockets of front, 2-For-One Hooded denim style faux leather jacket, Button detail on waist / Detail stitching at sides, HAND WASH ONLY / DO NOT BLEACH / LINE DRY / DO NOT IRON', 'category': "women's clothing", 'image': 'https://fakestoreapi.com/img/81XH0e8fefL._AC_UY879_.jpg', 'rating': {'rate': 2.9, 'count': 340}}
# {'id': 17, 'title': 'Rain Jacket Women Windbreaker Striped Climbing Raincoats', 'price': 39.99, 'description': "Lightweight perfet for trip or casual wear---Long sleeve with hooded, adjustable drawstring waist design. Button and zipper front closure raincoat, fully stripes Lined and The Raincoat has 2 side pockets are a good size to hold all kinds of things, it covers the hips, and the hood is generous but doesn't overdo it.Attached Cotton Lined Hood with Adjustable Drawstrings give it a real styled look.", 'category': "women's clothing", 'image': 'https://fakestoreapi.com/img/71HblAHs5xL._AC_UY879_-2.jpg', 'rating': {'rate': 3.8, 'count': 679}}
# {'id': 18, 'title': "MBJ Women's Solid Short Sleeve Boat Neck V ", 'price': 9.85, 'description': '95% RAYON 5% SPANDEX, Made in USA or Imported, Do Not Bleach, Lightweight fabric with great stretch for comfort, Ribbed on sleeves and neckline / Double stitching on bottom hem', 'category': "women's clothing", 'image': 'https://fakestoreapi.com/img/71z3kpMAYsL._AC_UY879_.jpg', 'rating': {'rate': 4.7, 'count': 130}}
# {'id': 19, 'title': "Opna Women's Short Sleeve Moisture", 'price': 7.95, 'description': '100% Polyester, Machine wash, 100% cationic polyester interlock, Machine Wash & Pre Shrunk for a Great Fit, Lightweight, roomy and highly breathable with moisture wicking fabric which helps to keep moisture away, Soft Lightweight Fabric with comfortable V-neck collar and a slimmer fit, delivers a sleek, more feminine silhouette and Added Comfort', 'category': "women's clothing", 'image': 'https://fakestoreapi.com/img/51eg55uWmdL._AC_UX679_.jpg', 'rating': {'rate': 4.5, 'count': 146}}
# {'id': 20, 'title': 'DANVOUY Womens T Shirt Casual Cotton Short', 'price': 12.99, 'description': '95%Cotton,5%Spandex, Features: Casual, Short Sleeve, Letter Print,V-Neck,Fashion Tees, The fabric is soft and has some stretch., Occasion: Casual/Office/Beach/School/Home/Street. Season: Spring,Summer,Autumn,Winter.', 'category': "women's clothing", 'image': 'https://fakestoreapi.com/img/61pHAEJ4NML._AC_UX679_.jpg', 'rating': {'rate': 3.6, 'count': 145}}

# %%
# print only titles of products
def get_field(products, name):
    for product in products:
        yield product[name]

# %%
for title in get_field(products,'title'):
    print(title)
# Out:
# Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops
# Mens Casual Premium Slim Fit T-Shirts
# Mens Cotton Jacket
# Mens Casual Slim Fit
# John Hardy Women's Legends Naga Gold & Silver Dragon Station Chain Bracelet
# Solid Gold Petite Micropave
# White Gold Plated Princess
# Pierced Owl Rose Gold Plated Stainless Steel Double
# WD 2TB Elements Portable External Hard Drive - USB 3.0
# SanDisk SSD PLUS 1TB Internal SSD - SATA III 6 Gb/s
# Silicon Power 256GB SSD 3D NAND A55 SLC Cache Performance Boost SATA III 2.5
# WD 4TB Gaming Drive Works with Playstation 4 Portable External Hard Drive
# Acer SB220Q bi 21.5 inches Full HD (1920 x 1080) IPS Ultra-Thin
# Samsung 49-Inch CHG90 144Hz Curved Gaming Monitor (LC49HG90DMNXZA) – Super Ultrawide Screen QLED
# BIYLACLESEN Women's 3-in-1 Snowboard Jacket Winter Coats
# Lock and Love Women's Removable Hooded Faux Leather Moto Biker Jacket
# Rain Jacket Women Windbreaker Striped Climbing Raincoats
# MBJ Women's Solid Short Sleeve Boat Neck V
# Opna Women's Short Sleeve Moisture
# DANVOUY Womens T Shirt Casual Cotton Short

# %%
for category in get_field(products,'category'):
    print(category)
# Out:
# men's clothing
# men's clothing
# men's clothing
# men's clothing
# jewelery
# jewelery
# jewelery
# jewelery
# electronics
# electronics
# electronics
# electronics
# electronics
# electronics
# women's clothing
# women's clothing
# women's clothing
# women's clothing
# women's clothing
# women's clothing

# %%
# Add a new product
# https://fakestoreapi.com/docs#p-new

new_product = { 
    "title": "test product",
    "price": 13.5,
    "description": "lorem ipsum set",
    "image": "https://i.pravatar.cc",
    "category": "electronic"
}

# %%
response = requests.post(
    url=PRODUCTS_URL,
    json=new_product
)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
id = response.json()['id']
id
# Out:
# 21

# %%
# update product

updated_product = { 
    "title": "test product",
    "price": 13.6,
    "description": "lorem ipsum set",
    "image": "https://i.pravatar.cc",
    "category": "electronic"
}

# %%
response = requests.put(
    url=f"{PRODUCTS_URL}/{id}",
    json=updated_product
)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'id': 21,
#  'title': 'test product',
#  'price': 13.6,
#  'description': 'lorem ipsum set',
#  'image': 'https://i.pravatar.cc',
#  'category': 'electronic'}

# %%
username = "shaikkhajaibrahim"
API_URL = f"https://api.github.com/users/{username}/repos"

# %%
response = requests.get(API_URL)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 188657635,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxODg2NTc2MzU=',
#   'name': 'ansible-deploy',
#   'full_name': 'shaikkhajaibrahim/ansible-deploy',
#   'private': False,
#   'owner': {'login': 'shaikkhajaibrahim',
#    'id': 2438317,
#    'node_id': 'MDQ6VXNlcjI0MzgzMTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2438317?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaikkhajaibrahim',
#    'html_url': 'https://github.com/shaikkhajaibrahim',
#    'followers_url': 'https://api.github.com/users/shaikkhajaibrahim/followers',
#    'following_url': 'https://api.github.com/users/shaikkhajaibrahim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shaikkhajaibrahim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shaikkhajaibrahim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shaikkhajaibrahim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shaikkhajaibrahim/orgs',
#    'repos_url': 'https://api.github.com/users/shaikkhajaibrahim/repos',
#    'events_url': 'https://api.github.com/users/shaikkhajaibrahim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shaikkhajaibrahim/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/shaikkhajaibrahim/ansible-deploy',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy',
#   'forks_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/forks',
#   'keys_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/teams',
#   'hooks_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/events',
#   'assignees_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/tags',
#   'blobs_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/languages',
#   'stargazers_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/subscription',
#   'commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/merges',
#   'archive_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/downloads',
#   'issues_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/shaikkhajaibrahim/ansible-deploy/deployments',
#   'created_at': '2019-05-26T08:23:21Z',
#   'updated_at': '2019-11-23T03:36:04Z',
#   'pushed_at': '2019-05-26T08:24:50Z',
#   'git_url': 'git://github.com/shaikkhajaibrahim/ansible-deploy.git',
#   'ssh_url': 'git@github.com:shaikkhajaibrahim/ansible-deploy.git',
#   'clone_url': 'https://github.com/shaikkhajaibrahim/ansible-deploy.git',
#   'svn_url': 'https://github.com/shaikkhajaibrahim/ansible-deploy',
#   'homepage': None,
#   'size': 29,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 15,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 15,
#   'open_issues': 0,
#   'watchers': 2,
#   'default_branch': 'master'},
#  {'id': 53113188,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk1MzExMzE4OA==',
#   'name': 'APITesting',
#   'full_name': 'shaikkhajaibrahim/APITesting',
#   'private': False,
#   'owner': {'login': 'shaikkhajaibrahim',
#    'id': 2438317,
#    'node_id': 'MDQ6VXNlcjI0MzgzMTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2438317?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaikkhajaibrahim',
#    'html_url': 'https://github.com/shaikkhajaibrahim',
#    'followers_url': 'https://api.github.com/users/shaikkhajaibrahim/followers',
#    'following_url': 'https://api.github.com/users/shaikkhajaibrahim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shaikkhajaibrahim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shaikkhajaibrahim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shaikkhajaibrahim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shaikkhajaibrahim/orgs',
#    'repos_url': 'https://api.github.com/users/shaikkhajaibrahim/repos',
#    'events_url': 'https://api.github.com/users/shaikkhajaibrahim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shaikkhajaibrahim/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/shaikkhajaibrahim/APITesting',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting',
#   'forks_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/forks',
#   'keys_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/teams',
#   'hooks_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/hooks',
#   'issue_events_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/events',
#   'assignees_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/tags',
#   'blobs_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/languages',
#   'stargazers_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/stargazers',
#   'contributors_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/contributors',
#   'subscribers_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/subscribers',
#   'subscription_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/subscription',
#   'commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/merges',
#   'archive_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/downloads',
#   'issues_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/shaikkhajaibrahim/APITesting/deployments',
#   'created_at': '2016-03-04T06:33:07Z',
#   'updated_at': '2016-03-04T06:33:07Z',
#   'pushed_at': '2018-09-22T16:56:22Z',
#   'git_url': 'git://github.com/shaikkhajaibrahim/APITesting.git',
#   'ssh_url': 'git@github.com:shaikkhajaibrahim/APITesting.git',
#   'clone_url': 'https://github.com/shaikkhajaibrahim/APITesting.git',
#   'svn_url': 'https://github.com/shaikkhajaibrahim/APITesting',
#   'homepage': None,
#   'size': 0,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 605385258,
#   'node_id': 'R_kgDOJBVyKg',
#   'name': 'branches_demo',
#   'full_name': 'shaikkhajaibrahim/branches_demo',
#   'private': False,
#   'owner': {'login': 'shaikkhajaibrahim',
#    'id': 2438317,
#    'node_id': 'MDQ6VXNlcjI0MzgzMTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2438317?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaikkhajaibrahim',
#    'html_url': 'https://github.com/shaikkhajaibrahim',
#    'followers_url': 'https://api.github.com/users/shaikkhajaibrahim/followers',
#    'following_url': 'https://api.github.com/users/shaikkhajaibrahim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shaikkhajaibrahim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shaikkhajaibrahim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shaikkhajaibrahim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shaikkhajaibrahim/orgs',
#    'repos_url': 'https://api.github.com/users/shaikkhajaibrahim/repos',
#    'events_url': 'https://api.github.com/users/shaikkhajaibrahim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shaikkhajaibrahim/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/shaikkhajaibrahim/branches_demo',
#   'description': 'This is for learning purposes',
#   'fork': False,
#   'url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo',
#   'forks_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/forks',
#   'keys_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/teams',
#   'hooks_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/events',
#   'assignees_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/tags',
#   'blobs_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/languages',
#   'stargazers_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/subscription',
#   'commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/merges',
#   'archive_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/downloads',
#   'issues_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/shaikkhajaibrahim/branches_demo/deployments',
#   'created_at': '2023-02-23T03:18:56Z',
#   'updated_at': '2023-02-23T03:22:58Z',
#   'pushed_at': '2023-02-23T03:29:26Z',
#   'git_url': 'git://github.com/shaikkhajaibrahim/branches_demo.git',
#   'ssh_url': 'git@github.com:shaikkhajaibrahim/branches_demo.git',
#   'clone_url': 'https://github.com/shaikkhajaibrahim/branches_demo.git',
#   'svn_url': 'https://github.com/shaikkhajaibrahim/branches_demo',
#   'homepage': None,
#   'size': 2,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 68178475,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2ODE3ODQ3NQ==',
#   'name': 'BroadleafCommerce',
#   'full_name': 'shaikkhajaibrahim/BroadleafCommerce',
#   'private': False,
#   'owner': {'login': 'shaikkhajaibrahim',
#    'id': 2438317,
#    'node_id': 'MDQ6VXNlcjI0MzgzMTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2438317?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaikkhajaibrahim',
#    'html_url': 'https://github.com/shaikkhajaibrahim',
#    'followers_url': 'https://api.github.com/users/shaikkhajaibrahim/followers',
#    'following_url': 'https://api.github.com/users/shaikkhajaibrahim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shaikkhajaibrahim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shaikkhajaibrahim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shaikkhajaibrahim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shaikkhajaibrahim/orgs',
#    'repos_url': 'https://api.github.com/users/shaikkhajaibrahim/repos',
#    'events_url': 'https://api.github.com/users/shaikkhajaibrahim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shaikkhajaibrahim/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/shaikkhajaibrahim/BroadleafCommerce',
#   'description': 'Broadleaf Commerce - Enterprise eCommerce framework based on Spring',
#   'fork': True,
#   'url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce',
#   'forks_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/forks',
#   'keys_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/teams',
#   'hooks_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/hooks',
#   'issue_events_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/events',
#   'assignees_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/tags',
#   'blobs_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/languages',
#   'stargazers_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/stargazers',
#   'contributors_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/contributors',
#   'subscribers_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/subscribers',
#   'subscription_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/subscription',
#   'commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/merges',
#   'archive_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/downloads',
#   'issues_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/shaikkhajaibrahim/BroadleafCommerce/deployments',
#   'created_at': '2016-09-14T06:10:52Z',
#   'updated_at': '2020-03-05T12:22:56Z',
#   'pushed_at': '2018-09-22T17:01:22Z',
#   'git_url': 'git://github.com/shaikkhajaibrahim/BroadleafCommerce.git',
#   'ssh_url': 'git@github.com:shaikkhajaibrahim/BroadleafCommerce.git',
#   'clone_url': 'https://github.com/shaikkhajaibrahim/BroadleafCommerce.git',
#   'svn_url': 'https://github.com/shaikkhajaibrahim/BroadleafCommerce',
#   'homepage': 'http://www.broadleafcommerce.com',
#   'size': 257322,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Java',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 5,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 5,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'BroadleafCommerce-4.0.x'},
#  {'id': 92048002,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk5MjA0ODAwMg==',
#   'name': 'caleydo',
#   'full_name': 'shaikkhajaibrahim/caleydo',
#   'private': False,
#   'owner': {'login': 'shaikkhajaibrahim',
#    'id': 2438317,
#    'node_id': 'MDQ6VXNlcjI0MzgzMTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2438317?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaikkhajaibrahim',
#    'html_url': 'https://github.com/shaikkhajaibrahim',
#    'followers_url': 'https://api.github.com/users/shaikkhajaibrahim/followers',
#    'following_url': 'https://api.github.com/users/shaikkhajaibrahim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shaikkhajaibrahim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shaikkhajaibrahim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shaikkhajaibrahim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shaikkhajaibrahim/orgs',
#    'repos_url': 'https://api.github.com/users/shaikkhajaibrahim/repos',
#    'events_url': 'https://api.github.com/users/shaikkhajaibrahim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shaikkhajaibrahim/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/shaikkhajaibrahim/caleydo',
#   'description': 'Caleydo - Visualization for Molecular Biology',
#   'fork': True,
#   'url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo',
#   'forks_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/forks',
#   'keys_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/teams',
#   'hooks_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/events',
#   'assignees_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/tags',
#   'blobs_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/languages',
#   'stargazers_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/subscription',
#   'commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/merges',
#   'archive_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/downloads',
#   'issues_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/shaikkhajaibrahim/caleydo/deployments',
#   'created_at': '2017-05-22T11:51:48Z',
#   'updated_at': '2017-05-22T11:51:56Z',
#   'pushed_at': '2016-12-15T17:07:10Z',
#   'git_url': 'git://github.com/shaikkhajaibrahim/caleydo.git',
#   'ssh_url': 'git@github.com:shaikkhajaibrahim/caleydo.git',
#   'clone_url': 'https://github.com/shaikkhajaibrahim/caleydo.git',
#   'svn_url': 'https://github.com/shaikkhajaibrahim/caleydo',
#   'homepage': 'http://caleydo.org',
#   'size': 1488009,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Java',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'bsd-3-clause',
#    'name': 'BSD 3-Clause "New" or "Revised" License',
#    'spdx_id': 'BSD-3-Clause',
#    'url': 'https://api.github.com/licenses/bsd-3-clause',
#    'node_id': 'MDc6TGljZW5zZTU='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'develop'},
#  {'id': 50822536,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk1MDgyMjUzNg==',
#   'name': 'CarManager',
#   'full_name': 'shaikkhajaibrahim/CarManager',
#   'private': False,
#   'owner': {'login': 'shaikkhajaibrahim',
#    'id': 2438317,
#    'node_id': 'MDQ6VXNlcjI0MzgzMTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2438317?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaikkhajaibrahim',
#    'html_url': 'https://github.com/shaikkhajaibrahim',
#    'followers_url': 'https://api.github.com/users/shaikkhajaibrahim/followers',
#    'following_url': 'https://api.github.com/users/shaikkhajaibrahim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shaikkhajaibrahim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shaikkhajaibrahim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shaikkhajaibrahim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shaikkhajaibrahim/orgs',
#    'repos_url': 'https://api.github.com/users/shaikkhajaibrahim/repos',
#    'events_url': 'https://api.github.com/users/shaikkhajaibrahim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shaikkhajaibrahim/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/shaikkhajaibrahim/CarManager',
#   'description': 'A sample used for various Web API examples',
#   'fork': True,
#   'url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager',
#   'forks_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/forks',
#   'keys_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/teams',
#   'hooks_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/hooks',
#   'issue_events_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/events',
#   'assignees_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/tags',
#   'blobs_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/languages',
#   'stargazers_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/stargazers',
#   'contributors_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/contributors',
#   'subscribers_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/subscribers',
#   'subscription_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/subscription',
#   'commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/merges',
#   'archive_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/downloads',
#   'issues_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/shaikkhajaibrahim/CarManager/deployments',
#   'created_at': '2016-02-01T07:32:46Z',
#   'updated_at': '2016-02-01T07:32:47Z',
#   'pushed_at': '2018-09-22T17:06:22Z',
#   'git_url': 'git://github.com/shaikkhajaibrahim/CarManager.git',
#   'ssh_url': 'git@github.com:shaikkhajaibrahim/CarManager.git',
#   'clone_url': 'https://github.com/shaikkhajaibrahim/CarManager.git',
#   'svn_url': 'https://github.com/shaikkhajaibrahim/CarManager',
#   'homepage': None,
#   'size': 2619,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'C#',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 2,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 77281256,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3NzI4MTI1Ng==',
#   'name': 'chefdemo',
#   'full_name': 'shaikkhajaibrahim/chefdemo',
#   'private': False,
#   'owner': {'login': 'shaikkhajaibrahim',
#    'id': 2438317,
#    'node_id': 'MDQ6VXNlcjI0MzgzMTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2438317?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaikkhajaibrahim',
#    'html_url': 'https://github.com/shaikkhajaibrahim',
#    'followers_url': 'https://api.github.com/users/shaikkhajaibrahim/followers',
#    'following_url': 'https://api.github.com/users/shaikkhajaibrahim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shaikkhajaibrahim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shaikkhajaibrahim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shaikkhajaibrahim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shaikkhajaibrahim/orgs',
#    'repos_url': 'https://api.github.com/users/shaikkhajaibrahim/repos',
#    'events_url': 'https://api.github.com/users/shaikkhajaibrahim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shaikkhajaibrahim/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/shaikkhajaibrahim/chefdemo',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo',
#   'forks_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/forks',
#   'keys_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/teams',
#   'hooks_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/events',
#   'assignees_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/tags',
#   'blobs_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/languages',
#   'stargazers_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/subscription',
#   'commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/merges',
#   'archive_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/downloads',
#   'issues_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/shaikkhajaibrahim/chefdemo/deployments',
#   'created_at': '2016-12-24T12:04:32Z',
#   'updated_at': '2019-11-23T03:36:17Z',
#   'pushed_at': '2018-09-22T17:36:23Z',
#   'git_url': 'git://github.com/shaikkhajaibrahim/chefdemo.git',
#   'ssh_url': 'git@github.com:shaikkhajaibrahim/chefdemo.git',
#   'clone_url': 'https://github.com/shaikkhajaibrahim/chefdemo.git',
#   'svn_url': 'https://github.com/shaikkhajaibrahim/chefdemo',
#   'homepage': None,
#   'size': 4,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Ruby',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'master'},
#  {'id': 77752200,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3Nzc1MjIwMA==',
#   'name': 'ChefProjects',
#   'full_name': 'shaikkhajaibrahim/ChefProjects',
#   'private': False,
#   'owner': {'login': 'shaikkhajaibrahim',
#    'id': 2438317,
#    'node_id': 'MDQ6VXNlcjI0MzgzMTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2438317?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaikkhajaibrahim',
#    'html_url': 'https://github.com/shaikkhajaibrahim',
#    'followers_url': 'https://api.github.com/users/shaikkhajaibrahim/followers',
#    'following_url': 'https://api.github.com/users/shaikkhajaibrahim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shaikkhajaibrahim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shaikkhajaibrahim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shaikkhajaibrahim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shaikkhajaibrahim/orgs',
#    'repos_url': 'https://api.github.com/users/shaikkhajaibrahim/repos',
#    'events_url': 'https://api.github.com/users/shaikkhajaibrahim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shaikkhajaibrahim/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/shaikkhajaibrahim/ChefProjects',
#   'description': 'This project contains chef implementations',
#   'fork': True,
#   'url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects',
#   'forks_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/forks',
#   'keys_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/teams',
#   'hooks_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/hooks',
#   'issue_events_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/events',
#   'assignees_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/tags',
#   'blobs_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/languages',
#   'stargazers_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/stargazers',
#   'contributors_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/contributors',
#   'subscribers_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/subscribers',
#   'subscription_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/subscription',
#   'commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/merges',
#   'archive_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/downloads',
#   'issues_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/shaikkhajaibrahim/ChefProjects/deployments',
#   'created_at': '2016-12-31T18:44:55Z',
#   'updated_at': '2019-11-23T03:36:34Z',
#   'pushed_at': '2018-09-22T17:11:22Z',
#   'git_url': 'git://github.com/shaikkhajaibrahim/ChefProjects.git',
#   'ssh_url': 'git@github.com:shaikkhajaibrahim/ChefProjects.git',
#   'clone_url': 'https://github.com/shaikkhajaibrahim/ChefProjects.git',
#   'svn_url': 'https://github.com/shaikkhajaibrahim/ChefProjects',
#   'homepage': None,
#   'size': 0,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 2,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'master'},
#  {'id': 77431129,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3NzQzMTEyOQ==',
#   'name': 'ChefZone',
# ...
#   'git_refs_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/languages',
#   'stargazers_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/subscription',
#   'commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/merges',
#   'archive_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/downloads',
#   'issues_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/shaikkhajaibrahim/HelmSampleDemo/deployments',
#   'created_at': '2023-11-14T08:33:03Z',
#   'updated_at': '2023-11-14T08:33:03Z',
#   'pushed_at': '2023-11-14T08:33:03Z',
#   'git_url': 'git://github.com/shaikkhajaibrahim/HelmSampleDemo.git',
#   'ssh_url': 'git@github.com:shaikkhajaibrahim/HelmSampleDemo.git',
#   'clone_url': 'https://github.com/shaikkhajaibrahim/HelmSampleDemo.git',
#   'svn_url': 'https://github.com/shaikkhajaibrahim/HelmSampleDemo',
#   'homepage': None,
#   'size': 0,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 53295970,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk1MzI5NTk3MA==',
#   'name': 'idea-soapui-plugin',
#   'full_name': 'shaikkhajaibrahim/idea-soapui-plugin',
#   'private': False,
#   'owner': {'login': 'shaikkhajaibrahim',
#    'id': 2438317,
#    'node_id': 'MDQ6VXNlcjI0MzgzMTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2438317?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaikkhajaibrahim',
#    'html_url': 'https://github.com/shaikkhajaibrahim',
#    'followers_url': 'https://api.github.com/users/shaikkhajaibrahim/followers',
#    'following_url': 'https://api.github.com/users/shaikkhajaibrahim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shaikkhajaibrahim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shaikkhajaibrahim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shaikkhajaibrahim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shaikkhajaibrahim/orgs',
#    'repos_url': 'https://api.github.com/users/shaikkhajaibrahim/repos',
#    'events_url': 'https://api.github.com/users/shaikkhajaibrahim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shaikkhajaibrahim/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/shaikkhajaibrahim/idea-soapui-plugin',
#   'description': 'integrates SoapUI functionality into Intellij',
#   'fork': True,
#   'url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin',
#   'forks_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/forks',
#   'keys_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/teams',
#   'hooks_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/hooks',
#   'issue_events_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/events',
#   'assignees_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/tags',
#   'blobs_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/languages',
#   'stargazers_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/stargazers',
#   'contributors_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/contributors',
#   'subscribers_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/subscribers',
#   'subscription_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/subscription',
#   'commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/merges',
#   'archive_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/downloads',
#   'issues_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/shaikkhajaibrahim/idea-soapui-plugin/deployments',
#   'created_at': '2016-03-07T04:32:30Z',
#   'updated_at': '2016-03-07T04:32:31Z',
#   'pushed_at': '2014-06-06T23:22:30Z',
#   'git_url': 'git://github.com/shaikkhajaibrahim/idea-soapui-plugin.git',
#   'ssh_url': 'git@github.com:shaikkhajaibrahim/idea-soapui-plugin.git',
#   'clone_url': 'https://github.com/shaikkhajaibrahim/idea-soapui-plugin.git',
#   'svn_url': 'https://github.com/shaikkhajaibrahim/idea-soapui-plugin',
#   'homepage': None,
#   'size': 140,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Java',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 2,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 481033449,
#   'node_id': 'R_kgDOHKv86Q',
#   'name': 'InventoryService',
#   'full_name': 'shaikkhajaibrahim/InventoryService',
#   'private': False,
#   'owner': {'login': 'shaikkhajaibrahim',
#    'id': 2438317,
#    'node_id': 'MDQ6VXNlcjI0MzgzMTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2438317?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaikkhajaibrahim',
#    'html_url': 'https://github.com/shaikkhajaibrahim',
#    'followers_url': 'https://api.github.com/users/shaikkhajaibrahim/followers',
#    'following_url': 'https://api.github.com/users/shaikkhajaibrahim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shaikkhajaibrahim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shaikkhajaibrahim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shaikkhajaibrahim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shaikkhajaibrahim/orgs',
#    'repos_url': 'https://api.github.com/users/shaikkhajaibrahim/repos',
#    'events_url': 'https://api.github.com/users/shaikkhajaibrahim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shaikkhajaibrahim/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/shaikkhajaibrahim/InventoryService',
#   'description': 'This repository will hold inventory service code',
#   'fork': True,
#   'url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService',
#   'forks_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/forks',
#   'keys_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/teams',
#   'hooks_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/hooks',
#   'issue_events_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/events',
#   'assignees_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/tags',
#   'blobs_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/languages',
#   'stargazers_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/stargazers',
#   'contributors_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/contributors',
#   'subscribers_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/subscribers',
#   'subscription_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/subscription',
#   'commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/merges',
#   'archive_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/downloads',
#   'issues_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/shaikkhajaibrahim/InventoryService/deployments',
#   'created_at': '2022-04-13T01:47:46Z',
#   'updated_at': '2022-04-13T01:49:43Z',
#   'pushed_at': '2022-04-13T01:49:40Z',
#   'git_url': 'git://github.com/shaikkhajaibrahim/InventoryService.git',
#   'ssh_url': 'git@github.com:shaikkhajaibrahim/InventoryService.git',
#   'clone_url': 'https://github.com/shaikkhajaibrahim/InventoryService.git',
#   'svn_url': 'https://github.com/shaikkhajaibrahim/InventoryService',
#   'homepage': None,
#   'size': 11,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'}]
